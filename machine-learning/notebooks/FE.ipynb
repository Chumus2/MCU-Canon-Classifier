# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MultiLabelBinarizer

from pathlib import Path
import warnings

# %%
warnings.filterwarnings("ignore")

ACCENT_PALETTE = ['#58a6ff', '#3fb950', '#f78166', '#d2a8ff', '#ffa657', '#79c0ff', '#f85149', '#56d4dd']

pd.set_option({
    "display.max_rows": None,
    "display.max_columns": None,
    "display.width": None,
    "display.max_colwidth": None,
})

plt.rcParams.update({
    'figure.facecolor': '#0d1117',

    'axes.facecolor': '#161b22',
    'axes.edgecolor': '#30363d',
    'axes.labelcolor': '#c9d1d9',
    'axes.titlecolor': '#e6edf3',
    'axes.prop_cycle': plt.cycler(color=ACCENT_PALETTE),

    'xtick.color': '#8b949e',
    'ytick.color': '#8b949e',
    'text.color': '#c9d1d9',

    'axes.grid': True,
    'axes.axisbelow': True,
    'grid.color': '#cccccc',
    'grid.linestyle': "--",
    'grid.alpha': 0.75,

    'legend.facecolor': '#161b22',
    'legend.edgecolor': '#30363d',

    'font.family': 'DejaVu Sans',
    'axes.titlesize': 14,
    'axes.labelsize': 11,
})

sns.set_palette(ACCENT_PALETTE)

# %%
def load_data(path: str) -> pd.DataFrame:
    data_path = Path(path)

    if not data_path.exists():
        raise FileNotFoundError(f'{data_path} does not exist')

    return pd.read_csv(data_path)

df = load_data("../data/cleaned-data/cleaned-data.csv")

# %%
print("==========INFO==========\n")
print(f"Df shape: {df.shape}\n")
print(f"Df info: {df.info()}\n")
print(f"Df describe: {df.describe()}\n")
# Out:
# ==========INFO==========
#
# Df shape: (161, 50)
#
# <class 'pandas.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 50 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    161 non-null    int64
#  1   title                 161 non-null    str
#  2   year                  161 non-null    int64
#  3   type                  161 non-null    str
#  4   rated                 161 non-null    str
#  5   runtime_min           161 non-null    float64
#  6   genre                 161 non-null    str
#  7   director              161 non-null    str
#  8   writer                161 non-null    str
#  9   actors                161 non-null    str
#  10  plot                  161 non-null    str
#  11  language              161 non-null    str
#  12  country               161 non-null    str
#  13  awards                161 non-null    str
#  14  imdb_rating           161 non-null    float64
#  15  imdb_votes            161 non-null    float64
#  16  rt_score              161 non-null    float64
#  17  metacritic_score      161 non-null    float64
#  18  mcu_phase             161 non-null    str
#  19  universe              161 non-null    str
#  20  decade                161 non-null    str
#  21  age_years             161 non-null    int64
#  22  is_animated           161 non-null    int64
#  23  is_tv_series          161 non-null    int64
#  24  is_mcu_canon          161 non-null    int64
#  25  tmdb_genres           161 non-null    str
#  26  tmdb_rating           161 non-null    float64
#  27  tmdb_votes            161 non-null    float64
#  28  popularity            161 non-null    float64
#  29  top5_cast             161 non-null    str
#  30  directors             161 non-null    str
#  31  producers             161 non-null    str
#  32  composer              161 non-null    str
#  33  tmdb_keywords         161 non-null    str
#  34  production_countries  161 non-null    str
#  35  spoken_languages      161 non-null    str
#  36  episode_count         161 non-null    float64
#  37  season_count          161 non-null    float64
#  38  status                161 non-null    str
#  39  tagline               161 non-null    str
#  40  revenue_log           161 non-null    float64
#  41  budget_log            161 non-null    float64
#  42  box_office_log        161 non-null    float64
#  43  document              161 non-null    str
#  44  cast_count            161 non-null    float64
#  45  top_actor             161 non-null    str
#  46  IMDb                  161 non-null    float64
#  47  Metacritic            161 non-null    float64
#  48  Rotten Tomatoes       161 non-null    float64
#  49  TMDB                  161 non-null    float64
# dtypes: float64(18), int64(6), str(26)
# memory usage: 63.0 KB
# Df info: None
#
# Df describe:                id         year  runtime_min  imdb_rating  imdb_votes  \
# count  161.000000   161.000000   161.000000   161.000000  161.000000
# mean    81.000000  2012.602484   115.453416     6.632609   11.940367
# std     46.620811    12.995807    20.257082     0.970104    2.310689
# min      1.000000  1944.000000    24.000000     3.200000    2.484907
# 25%     41.000000  2009.000000   115.000000     6.500000   12.092557
# 50%     81.000000  2017.000000   117.000000     6.750000   12.664111
# 75%    121.000000  2021.000000   121.000000     7.100000   13.205397
# max    161.000000  2026.000000   181.000000     8.700000   14.257185
#
#          rt_score  metacritic_score   age_years  is_animated  is_tv_series  \
# count  161.000000        161.000000  161.000000   161.000000    161.000000
# mean    71.173913         62.229814   12.397516     0.062112      0.080745
# std     18.930982          9.801306   12.995807     0.242112      0.273294
# min      9.000000         27.000000   -1.000000     0.000000      0.000000
# 25%     76.000000         64.000000    4.000000     0.000000      0.000000
# 50%     76.000000         64.000000    8.000000     0.000000      0.000000
# 75%     76.000000         64.000000   16.000000     0.000000      0.000000
# max     97.000000         88.000000   81.000000     1.000000      1.000000
#
#        is_mcu_canon  tmdb_rating  tmdb_votes  popularity  episode_count  \
# count    161.000000   161.000000  161.000000  161.000000     161.000000
# mean       0.546584     6.606509    7.890807    9.926462       0.739130
# std        0.499378     1.019839    2.296027    9.375648       3.764176
# min        0.000000     0.000000    0.000000    0.132500       0.000000
# 25%        0.000000     6.300000    7.185387    4.252500       0.000000
# 50%        1.000000     6.745000    8.745921    8.197300       0.000000
# 75%        1.000000     7.066000    9.323223   11.685800       0.000000
# max        1.000000     8.393000   10.555630   53.601000      40.000000
#
#        season_count  revenue_log  budget_log  box_office_log  cast_count  \
# count    161.000000   161.000000  161.000000      161.000000  161.000000
# mean       0.086957    19.737645   18.564485       19.173957   10.111801
# std        0.342624     0.928344    0.754687        0.554500    6.782324
# min        0.000000    13.931636   14.220976       15.901304    0.000000
# 25%        0.000000    19.707423   18.603002       19.193788    0.000000
# 50%        0.000000    19.707423   18.603002       19.193788   15.000000
# 75%        0.000000    19.987081   18.826146       19.193788   15.000000
# max        2.000000    21.752685   19.690441       20.570549   15.000000
#
#              IMDb  Metacritic  Rotten Tomatoes        TMDB
# count  161.000000  161.000000       161.000000  161.000000
# mean     6.564706    6.004167         6.603846    6.595138
# std      0.965961    0.960042         1.826042    0.873295
# min      3.200000    2.700000         0.900000    3.800000
# 25%      6.500000    6.004167         6.603846    6.300000
# 50%      6.564706    6.004167         6.603846    6.554427
# 75%      7.100000    6.100000         7.300000    7.066000
# max      8.700000    8.800000         9.700000    8.393000

# %%
similar = {
    "imdb_rating": "IMDb",
    "rt_score": "Rotten Tomatoes",
    "metacritic_score": "Metacritic",
    "tmdb_rating": "TMDB",
}

for master_col, ratings_col in similar.items():
    diff = (df[master_col] - df[ratings_col]).abs()
    print(f"{master_col} vs {ratings_col}:")
    print(diff.describe())
    print(f"Max diff: {diff.max()}, rows with diff > 0.5: {(diff > 0.5).sum()}\n")

diff_rt = (df["rt_score"]/10 - df["Rotten Tomatoes"]).abs()
print(diff_rt.describe())

diff_meta = (df["metacritic_score"]/10 - df["Metacritic"]).abs()
print(diff_meta.describe())

df = df.drop(columns=list(similar.keys()))
# Out:
# imdb_rating vs IMDb:
# count    161.000000
# mean       0.067903
# std        0.089560
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.185294
# max        0.185294
# dtype: float64
# Max diff: 0.18529411764705817, rows with diff > 0.5: 0
#
# rt_score vs Rotten Tomatoes:
# count    161.000000
# mean      64.570067
# std       17.176376
# min        8.100000
# 25%       69.300000
# 50%       69.396154
# 75%       69.396154
# max       87.300000
# dtype: float64
# Max diff: 87.3, rows with diff > 0.5: 161
#
# metacritic_score vs Metacritic:
# count    161.000000
# mean      56.225647
# std        8.863052
# min       24.300000
# 25%       57.995833
# 50%       57.995833
# 75%       57.995833
# max       79.200000
# dtype: float64
# Max diff: 79.2, rows with diff > 0.5: 161
#
# tmdb_rating vs TMDB:
# count    161.000000
# mean       0.092793
# std        0.519448
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.190573
# max        6.554427
# dtype: float64
# Max diff: 6.554427350427351, rows with diff > 0.5: 1
#
# count    161.000000
# mean       0.513545
# std        0.499390
# min        0.000000
# 25%        0.000000
# 50%        0.996154
# 75%        0.996154
# max        0.996154
# dtype: float64
# count    161.000000
# mean       0.218815
# std        0.197424
# min        0.000000
# 25%        0.000000
# 50%        0.395833
# 75%        0.395833
# max        0.395833
# dtype: float64

# %%
print("==========STRING COLUMNS==========\n")
str_cols = df.select_dtypes(include="object").columns.tolist()
print(f"Str columns: {str_cols}")

df = df.drop(columns=["title", "top_actor"])

categorial_cols = ["type", "rated", "mcu_phase", "universe", "decade", "status", "language", "country"]
for col in categorial_cols:
    print(f"Categorial columns: {col} - {df[col].nunique()} values")

df = df.drop(columns=["language", "country"])

categorial_cols.remove("language")
categorial_cols.remove("country")
df = pd.get_dummies(df, columns=categorial_cols, drop_first=True)

unique_cols = ["director", "writer", "actors", "directors", "producers", "composer", "top5_cast", "tmdb_keywords"]
df = df.drop(columns=unique_cols)

text_cols = ["plot", "awards", "tagline", "document"]
df = df.drop(columns=text_cols)

print("\n==========REMAINING STRING COLUMNS==========")
print(df.select_dtypes(include="object").columns.tolist())
# Out:
# ==========STRING COLUMNS==========
#
# Str columns: ['title', 'type', 'rated', 'genre', 'director', 'writer', 'actors', 'plot', 'language', 'country', 'awards', 'mcu_phase', 'universe', 'decade', 'tmdb_genres', 'top5_cast', 'directors', 'producers', 'composer', 'tmdb_keywords', 'production_countries', 'spoken_languages', 'status', 'tagline', 'document', 'top_actor']
# Categorial columns: type - 3 values
# Categorial columns: rated - 11 values
# Categorial columns: mcu_phase - 7 values
# Categorial columns: universe - 5 values
# Categorial columns: decade - 7 values
# Categorial columns: status - 6 values
# Categorial columns: language - 45 values
# Categorial columns: country - 41 values
#
# ==========REMAINING STRING COLUMNS==========
# ['genre', 'tmdb_genres', 'production_countries', 'spoken_languages']

# %%
print(df[["genre", "tmdb_genres"]].head(10))
print(df.loc[[6, 7], ["genre", "tmdb_genres"]])

genre_values = set(g.strip() for row in df["genre"].str.split(",") for g in row)
tmdb_genre_values = set(g.strip() for row in df["tmdb_genres"].str.split(",") for g in row)

print(f"\nOnly in gender: {genre_values - tmdb_genre_values}")
print(f"Only in tmdb_genres: {tmdb_genre_values - genre_values}")
print(f"Main: {genre_values & tmdb_genre_values}")

genre_synonyms = {
    "Science Fiction": "Sci-Fi",
    "Sci-Fi & Fantasy": "Sci-Fi, Fantasy",
    "Action & Adventure": "Action, Adventure",
    "Talk": "Talk-Show",
    "Kids": "Family",
}

def normalize_genres(genre_str, synonyms):
    parts = [g.strip() for g in genre_str.split(",")]
    normalized = []
    for p in parts:
        replacement = synonyms.get(p, p)
        normalized.extend(r.strip() for r in replacement.split(","))
    return list(set(normalized))

df["tmdb_genres_norm"] = df["tmdb_genres"].apply(lambda x: normalize_genres(x, genre_synonyms))
df["genre_norm"] = df["genre"].apply(lambda x: normalize_genres(x, {}))

df["all_genres"] = df.apply(lambda row: list(set(row["genre_norm"]) | set(row["tmdb_genres_norm"])), axis=1)

df["is_tv_movie_format"] = df["tmdb_genres"].str.contains("TV Movie").astype(int)

df = df.drop(columns=["tmdb_genres", "genre", "tmdb_genres_norm", "genre_norm"])

mlb = MultiLabelBinarizer()
genre_encoded = pd.DataFrame(
    mlb.fit_transform(df["all_genres"]),
    columns=[f"genre_{g}" for g in mlb.classes_],
    index=df.index
)

df = pd.concat([df.drop(columns=["all_genres"]), genre_encoded], axis=1)

print(df.select_dtypes(include="object").columns.tolist())

prod_countries_values = set(c.strip() for row in df["production_countries"].str.split(",") for c in row)
spoken_lang_values = set(l.strip() for row in df["spoken_languages"].str.split(",") for l in row)

print("\n\n==========REMAINING COLUMNS==========")
print(f"Production countries ({len(prod_countries_values)}): {prod_countries_values}")
print(f"Spoken languages ({len(spoken_lang_values)}): {spoken_lang_values}")

df = df.drop(columns=["production_countries", "spoken_languages"])

print("\n==========DF AFTER ENCONDING==========")
print(df.info())
# Out:
#                        genre  \
# 0  Action, Adventure, Sci-Fi
# 1   Action, Adventure, Crime
# 2   Action, Adventure, Crime
# 3            Action, Fantasy
# 4                    Unknown
# 5    Action, Family, Fantasy
# 6      Short, Action, Sci-Fi
# 7   Action, Adventure, Crime
# 8  Action, Adventure, Sci-Fi
# 9  Action, Adventure, Sci-Fi
#
#                                              tmdb_genres
# 0                     Action, Adventure, Science Fiction
# 1                         Science Fiction, Action, Crime
# 2                         Science Fiction, Action, Crime
# 3  TV Movie, Action, Adventure, Fantasy, Science Fiction
# 4                         Science Fiction, Action, Drama
# 5           Action, Adventure, Family, Fantasy, TV Movie
# 6           Action, Adventure, Family, Fantasy, TV Movie
# 7                                                Unknown
# 8           Action, Adventure, Science Fiction, TV Movie
# 9               Action, Drama, Science Fiction, TV Movie
#                       genre                                   tmdb_genres
# 6     Short, Action, Sci-Fi  Action, Adventure, Family, Fantasy, TV Movie
# 7  Action, Adventure, Crime                                       Unknown
#
# Only in gender: {'Short', 'Talk-Show', 'Sci-Fi', 'Musical'}
# Only in tmdb_genres: {'Kids', 'Science Fiction', 'Action & Adventure', 'Sci-Fi & Fantasy', 'Talk', 'Romance', 'TV Movie', 'War'}
# Main: {'Fantasy', 'Animation', 'Documentary', 'Adventure', 'Action', 'Thriller', 'Horror', 'Family', 'Unknown', 'Comedy', 'Mystery', 'Drama', 'Crime'}
# ['production_countries', 'spoken_languages']
#
#
# ==========REMAINING COLUMNS==========
# Production countries (15): {'Poland', 'Australia', 'Germany', 'Canada', 'United Arab Emirates', 'China', 'Russia', 'Switzerland', 'United States of America', 'Croatia', 'Unknown', 'United Kingdom', 'Slovenia', 'Yugoslavia', 'Philippines'}
# Spoken languages (31): {'Latin', 'English', 'Persian', 'Korean', 'Romanian', 'Arabic', 'Vietnamese', 'Unknown', 'French', 'Urdu', 'Czech', 'Swahili', 'Greek', 'German', 'Tagalog', 'Italian', 'Russian', 'Norwegian', 'Dutch', 'Spanish', 'Mandarin', 'Malay', 'Portuguese', 'Turkish', 'Japanese', 'Uzbek', 'Hindi', 'Polish', 'Xhosa', 'Cantonese', 'Haitian; Haitian Creole'}
#
# ==========DF AFTER ENCONDING==========
# <class 'pandas.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 74 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          161 non-null    int64
#  1   year                        161 non-null    int64
#  2   runtime_min                 161 non-null    float64
#  3   imdb_votes                  161 non-null    float64
#  4   age_years                   161 non-null    int64
#  5   is_animated                 161 non-null    int64
#  6   is_tv_series                161 non-null    int64
#  7   is_mcu_canon                161 non-null    int64
#  8   tmdb_votes                  161 non-null    float64
#  9   popularity                  161 non-null    float64
#  10  episode_count               161 non-null    float64
#  11  season_count                161 non-null    float64
#  12  revenue_log                 161 non-null    float64
#  13  budget_log                  161 non-null    float64
#  14  box_office_log              161 non-null    float64
#  15  cast_count                  161 non-null    float64
#  16  IMDb                        161 non-null    float64
#  17  Metacritic                  161 non-null    float64
#  18  Rotten Tomatoes             161 non-null    float64
#  19  TMDB                        161 non-null    float64
#  20  type_movie                  161 non-null    bool
#  21  type_series                 161 non-null    bool
#  22  rated_Not Rated             161 non-null    bool
#  23  rated_PG                    161 non-null    bool
#  24  rated_PG-13                 161 non-null    bool
#  25  rated_R                     161 non-null    bool
#  26  rated_TV-14                 161 non-null    bool
#  27  rated_TV-MA                 161 non-null    bool
#  28  rated_TV-PG                 161 non-null    bool
#  29  rated_TV-Y7-FV              161 non-null    bool
#  30  rated_Unknown               161 non-null    bool
#  31  rated_Unrated               161 non-null    bool
#  32  mcu_phase_Phase 1           161 non-null    bool
#  33  mcu_phase_Phase 2           161 non-null    bool
#  34  mcu_phase_Phase 3           161 non-null    bool
#  35  mcu_phase_Phase 4           161 non-null    bool
#  36  mcu_phase_Phase 5/6         161 non-null    bool
#  37  mcu_phase_Pre-MCU           161 non-null    bool
#  38  universe_MCU                161 non-null    bool
#  39  universe_Netflix Marvel     161 non-null    bool
#  40  universe_Pre-MCU            161 non-null    bool
#  41  universe_Sony / Spider-Man  161 non-null    bool
#  42  decade_1970s                161 non-null    bool
#  43  decade_1980s                161 non-null    bool
#  44  decade_1990s                161 non-null    bool
#  45  decade_2000s                161 non-null    bool
#  46  decade_2010s                161 non-null    bool
#  47  decade_2020s                161 non-null    bool
#  48  status_Ended                161 non-null    bool
#  49  status_Post Production      161 non-null    bool
#  50  status_Released             161 non-null    bool
#  51  status_Returning Series     161 non-null    bool
#  52  status_Unknown              161 non-null    bool
#  53  is_tv_movie_format          161 non-null    int64
#  54  genre_Action                161 non-null    int64
#  55  genre_Adventure             161 non-null    int64
#  56  genre_Animation             161 non-null    int64
#  57  genre_Comedy                161 non-null    int64
#  58  genre_Crime                 161 non-null    int64
#  59  genre_Documentary           161 non-null    int64
#  60  genre_Drama                 161 non-null    int64
#  61  genre_Family                161 non-null    int64
#  62  genre_Fantasy               161 non-null    int64
#  63  genre_Horror                161 non-null    int64
#  64  genre_Musical               161 non-null    int64
#  65  genre_Mystery               161 non-null    int64
#  66  genre_Romance               161 non-null    int64
#  67  genre_Sci-Fi                161 non-null    int64
#  68  genre_Short                 161 non-null    int64
#  69  genre_TV Movie              161 non-null    int64
#  70  genre_Talk-Show             161 non-null    int64
#  71  genre_Thriller              161 non-null    int64
#  72  genre_Unknown               161 non-null    int64
#  73  genre_War                   161 non-null    int64
# dtypes: bool(33), float64(14), int64(27)
# memory usage: 56.9 KB
# None

# %%
corr_cols = [
    "runtime_min", "age_years", "revenue_log", "budget_log", "box_office_log",
    "imdb_votes", "tmdb_votes", "popularity", "cast_count",
    "IMDb", "Metacritic", "Rotten Tomatoes", "TMDB", "is_mcu_canon"
]

plt.figure(figsize=(20, 16))

sns.heatmap(
    df[corr_cols].corr(), annot=True, cmap="coolwarm", center=0, annot_kws={"size": 15}, fmt=".2f"
)

plt.title("Correlation Heatmap (Main)")
plt.xticks(rotation=45, ha="right", fontsize=8)
plt.yticks(fontsize=8)
plt.tight_layout()
plt.show()

# %%
mcu_cols = [c for c in remaining_cols if c.startswith(("mcu_phase_", "universe_", "decade_"))]

plt.figure(figsize=(20, 16))

sns.heatmap(
    df[mcu_cols + ["is_mcu_canon"]].corr(), annot=True, cmap="coolwarm", center=0, annot_kws={"size": 15}, fmt=".2f"
)

plt.title("Correlation Heatmap (MCU)")
plt.xticks(rotation=45, ha="right", fontsize=8)
plt.yticks(fontsize=8)
plt.tight_layout()
plt.show()

leaky_cols = [col for col in df.columns if col.startswith(("universe_", "mcu_phase_"))]
df = df.drop(columns=leaky_cols)

# %%
genre_cols = [col for col in remaining_cols if col.startswith("genre_")]

plt.figure(figsize=(20, 16))

sns.heatmap(
    df[genre_cols + ["is_mcu_canon"]].corr(), annot=True, cmap="coolwarm", center=0, annot_kws={"size": 15}, fmt=".2f"
)

plt.title("Correlation Heatmap (Genres)")
plt.xticks(rotation=45, ha="right", fontsize=8)
plt.yticks(fontsize=8)
plt.tight_layout()
plt.show()

leaky_cols = [col for col in df.columns if col.startswith(("universe_", "mcu_phase_"))]
df = df.drop(columns=leaky_cols)

# %%
USELESS_COLUMNS = [
    "cast_count", "tmdb_votes", "imdb_votes",
    "genre_Action", "genre_Adventure", "genre_Animation",
    "genre_Drama", "genre_Fantasy", "genre_Musical",
    "genre_War", "genre_Family", "genre_Unknown"
]

df = df.drop(columns=USELESS_COLUMNS)

print("==========DF AFTER DROPING==========")
print(df.info())
print(df.isna().sum())
print(df.duplicated().sum())
# Out:
# ==========DF AFTER DROPING==========
# <class 'pandas.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 52 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       161 non-null    int64
#  1   year                     161 non-null    int64
#  2   runtime_min              161 non-null    float64
#  3   age_years                161 non-null    int64
#  4   is_animated              161 non-null    int64
#  5   is_tv_series             161 non-null    int64
#  6   is_mcu_canon             161 non-null    int64
#  7   popularity               161 non-null    float64
#  8   episode_count            161 non-null    float64
#  9   season_count             161 non-null    float64
#  10  revenue_log              161 non-null    float64
#  11  budget_log               161 non-null    float64
#  12  box_office_log           161 non-null    float64
#  13  IMDb                     161 non-null    float64
#  14  Metacritic               161 non-null    float64
#  15  Rotten Tomatoes          161 non-null    float64
#  16  TMDB                     161 non-null    float64
#  17  type_movie               161 non-null    bool
#  18  type_series              161 non-null    bool
#  19  rated_Not Rated          161 non-null    bool
#  20  rated_PG                 161 non-null    bool
#  21  rated_PG-13              161 non-null    bool
#  22  rated_R                  161 non-null    bool
#  23  rated_TV-14              161 non-null    bool
#  24  rated_TV-MA              161 non-null    bool
#  25  rated_TV-PG              161 non-null    bool
#  26  rated_TV-Y7-FV           161 non-null    bool
#  27  rated_Unknown            161 non-null    bool
#  28  rated_Unrated            161 non-null    bool
#  29  decade_1970s             161 non-null    bool
#  30  decade_1980s             161 non-null    bool
#  31  decade_1990s             161 non-null    bool
#  32  decade_2000s             161 non-null    bool
#  33  decade_2010s             161 non-null    bool
#  34  decade_2020s             161 non-null    bool
#  35  status_Ended             161 non-null    bool
#  36  status_Post Production   161 non-null    bool
#  37  status_Released          161 non-null    bool
#  38  status_Returning Series  161 non-null    bool
#  39  status_Unknown           161 non-null    bool
#  40  is_tv_movie_format       161 non-null    int64
#  41  genre_Comedy             161 non-null    int64
#  42  genre_Crime              161 non-null    int64
#  43  genre_Documentary        161 non-null    int64
#  44  genre_Horror             161 non-null    int64
#  45  genre_Mystery            161 non-null    int64
#  46  genre_Romance            161 non-null    int64
#  47  genre_Sci-Fi             161 non-null    int64
#  48  genre_Short              161 non-null    int64
#  49  genre_TV Movie           161 non-null    int64
#  50  genre_Talk-Show          161 non-null    int64
#  51  genre_Thriller           161 non-null    int64
# dtypes: bool(23), float64(11), int64(18)
# memory usage: 40.2 KB
# None
# id                         0
# year                       0
# runtime_min                0
# age_years                  0
# is_animated                0
# is_tv_series               0
# is_mcu_canon               0
# popularity                 0
# episode_count              0
# season_count               0
# revenue_log                0
# budget_log                 0
# box_office_log             0
# IMDb                       0
# Metacritic                 0
# Rotten Tomatoes            0
# TMDB                       0
# type_movie                 0
# type_series                0
# rated_Not Rated            0
# rated_PG                   0
# rated_PG-13                0
# rated_R                    0
# rated_TV-14                0
# rated_TV-MA                0
# rated_TV-PG                0
# rated_TV-Y7-FV             0
# rated_Unknown              0
# rated_Unrated              0
# decade_1970s               0
# decade_1980s               0
# decade_1990s               0
# decade_2000s               0
# decade_2010s               0
# decade_2020s               0
# status_Ended               0
# status_Post Production     0
# status_Released            0
# status_Returning Series    0
# status_Unknown             0
# is_tv_movie_format         0
# genre_Comedy               0
# genre_Crime                0
# genre_Documentary          0
# genre_Horror               0
# genre_Mystery              0
# genre_Romance              0
# genre_Sci-Fi               0
# genre_Short                0
# genre_TV Movie             0
# genre_Talk-Show            0
# genre_Thriller             0
# dtype: int64
# 0
